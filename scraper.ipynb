# %%
from webscraper import WebScraper

    
with WebScraper() as scraper:
    content = scraper.scrape_page("https://nitter.net/search?f=tweets&q=from%3Aj0hnwang+OR+from%3Athe_jtop")
    if content:
        print(content)
# Out:
# 2025-02-05 10:55:25,838 - INFO - Chrome driver started successfully
# 2025-02-05 10:55:25,838 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang+OR+from%3Athe_jtop...
# 2025-02-05 10:55:34,829 - INFO - Content extracted successfully
# 2025-02-05 10:55:34,889 - INFO - Chrome driver closed successfully
# nitter
# Tweets
# Users
# John Wang
# @j0hnwang
# 1h
# Replying to @srachasaucee @jessepollak @CoinbaseDev
# this is the content i live for
# 1
# 1
# John Wang
# @j0hnwang
# 1h
# Replying to @khushkhushkhush @A_StarVC @aaruHQ
# congratz and good luck w aaru!
# 2
# J_T
# @the_jtop
# 4h
# Registration completed @infecteddotfun
# sig:0x102edf3af3f7abcd12ff15ea9a36be5aa6342c786b68eec4b2e8590ece88ab773bc057fe113da3999201773fc9b6b70521d76dfbde6368
# 1
# John Wang
# @j0hnwang
# 12h
# Registration completed @infecteddotfun
# sig:0xc658f662a5f24f5cb6f9b1583c6835601ba069fa40b3d1e07cfe8c414ac29e1b7df10b8f64737ac71ed7905d1d0eade00181e809f2314c
# 7
# 10
# John Wang
# @j0hnwang
# 12h
# Replying to @daddm3_ @heyjchu
# milady
# 1
# John Wang retweeted
# keshav
# @keshavchan
# Feb 3
# your moat is that you care—so much that you know about every seam, every edge case, every tiny friction most people would never notice. you also know that not all friction is bad, and you're wise enough to know the difference.
#
# this is not just a product for you. it’s obsession. the kind that makes things feel effortless for everyone else because you carry the weight of noticing. it’s rare, and it’s why the best products have a soul.
# Garry Tan
# @garrytan
# Feb 3
# The best founders I have ever worked with actually spot bugs in my software experience before I even do. They text me and say a fix is on its way.
#
# That is gardening. Being in the weeds and making sure things work. True craft looks like this. It is a lost art.
# 12
# 41
# 3
# 482
# John Wang
# @j0hnwang
# 12h
# Replying to @QwQiao
# mega gm
# 3
# John Wang
# @j0hnwang
# 13h
# Replying to @cory
# rest up cory, we need u!
# 2
# J_T
# @the_jtop
# 14h
# testing --- EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v) ... testing. erubg
# J_T
# @the_jtop
# 14h
# Testing (6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN..
# Testing
# John Wang retweeted
# mert | helius.dev
# @0xMert_
# 22 Oct 2024
# My guide to founder-led messaging
#
# 1) get over yourself. no one actually cares. they have a thousand other things to pay attention to during any given day.
#
# mfers wage multi century wars just so they will be remembered. youre gonna die sooner than you think, just get out there.
#
# 2) be yourself. talk about what you actually think — not what others want you to think or what others like.
#
# 3) use basic words and practice basic speaking and writing. it doesnt matter how great your ideas are if no one can understand them.
#
# 4) always tell the truth, but make the truth interesting with concrete examples and contrasts
#
# 5) do not outsource. it is literally main the job of the founder(s) to tell the story of the company, whether it's selling product, recruiting, or raising. if you are totally inept at this, hire someone to help you **full time**, if they're doing the 2nd most important job of the company, they should have tremendous skin in the game
#
# bonus: don't be boring
# Superteam UAE
# @SuperteamAE
# 22 Oct 2024
# we asked @0xMert_ to share a few tips on how to do Founder-led marketing
#
# here are 5 things he shared:
# 1/ get over yourself
# 2/ be authentic
# 3/ be articulate (and use simple words)
# 4/ tell the truth but make the truth fascinating
# 5/ never outsource to an agency
#
# bonus:
# - never have a process
# - stop being boring (make your announcements interesting)
#
# what other things would you like to learn from Mert?
# Enable hls playback
# 45
# 44
# 12
# 475
# John Wang
# @j0hnwang
# 16h
# Replying to @hunterjisaacson
# king shitt
# 1
# 4
# John Wang
# @j0hnwang
# 20h
# Replying to @0xyu2001 @TheReviken
# they removed most.
# 3
# 2
# John Wang
# @j0hnwang
# 21h
# Replying to @AR15CRYPTO
# one of us @AR15CRYPTO
# 2
# John Wang
# @j0hnwang
# 21h
# Replying to @kolelee_
# AGI soon
# 2
# John Wang
# @j0hnwang
# 22h
# Replying to @a1lon9
# +1
# John Wang
# @j0hnwang
# 22h
# Replying to @AR15CRYPTO @probablynothing
# zigma energy
# 1
# John Wang
# @j0hnwang
# 23h
# Replying to @pvp_dot_trade
# studying ✍🏽
# 2
# John Wang
# @j0hnwang
# Feb 3
# Replying to @TheReviken
# 1
# 1
# John Wang
# @j0hnwang
# Feb 3
# Replying to @kmao37
# i reused the picture lol
# 1
# 2
# Load more

# %%
from webscraper import WebScraper
from typing import List, Optional
from urllib.parse import quote

def scrape_twitter_users(usernames: List[str]) -> Optional[str]:
    """
    Scrape tweets from multiple Twitter/X users using Nitter.
    
    Args:
        usernames (List[str]): List of Twitter usernames without the @ symbol
        
    Returns:
        Optional[str]: Combined content of tweets if successful, None if failed
    """
    if not usernames:
        return None
        
    # Build the search query
    query = " OR ".join(f"from:{username}" for username in usernames)
    encoded_query = quote(query)
    url = f"https://nitter.net/search?f=tweets&q={encoded_query}"
    
    with WebScraper() as scraper:
        content = scraper.scrape_page(url)
        return content
    

sample = scrape_twitter_users(["j0hnwang", "the_jtop", "Shmurda"])
# Out:
# 2025-02-05 21:30:14,039 - INFO - Chrome driver started successfully
# 2025-02-05 21:30:14,041 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# 2025-02-05 21:30:21,301 - INFO - Content extracted successfully
# 2025-02-05 21:30:21,302 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 1 took 7.87 seconds
# 2025-02-05 21:30:27,303 - INFO - Content extracted successfully
# 2025-02-05 21:30:27,303 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 2 took 6.00 seconds
# 2025-02-05 21:30:33,379 - INFO - Content extracted successfully
# 2025-02-05 21:30:33,379 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 3 took 6.08 seconds
# 2025-02-05 21:30:39,394 - INFO - Content extracted successfully
# 2025-02-05 21:30:39,395 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 4 took 6.02 seconds
# 2025-02-05 21:30:45,291 - INFO - Content extracted successfully
# 2025-02-05 21:30:45,291 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 5 took 5.90 seconds
# 2025-02-05 21:30:51,310 - INFO - Content extracted successfully
# 2025-02-05 21:30:51,311 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 6 took 6.02 seconds
# 2025-02-05 21:30:57,235 - INFO - Content extracted successfully
# 2025-02-05 21:30:57,235 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 7 took 5.92 seconds
# 2025-02-05 21:31:03,272 - INFO - Content extracted successfully
# 2025-02-05 21:31:03,272 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 8 took 6.04 seconds
# 2025-02-05 21:31:09,288 - INFO - Content extracted successfully
# 2025-02-05 21:31:09,288 - INFO - Fetching https://nitter.net/search?f=tweets&q=from%3Aj0hnwang%20OR%20from%3Athe_jtop%20OR%20from%3AShmurda...
# Scrape 9 took 6.02 seconds
# 2025-02-05 21:31:15,254 - INFO - Content extracted successfully
# 2025-02-05 21:31:15,315 - INFO - Chrome driver closed successfully
# Scrape 10 took 5.97 seconds

# %%
def extract_ca(text):
    # Replace non-alphanumeric characters with spaces
    cleaned_text = ''.join(char if char.isalnum() else ' ' for char in text)
    
    # Split into words
    words = cleaned_text.split()
    
    # Find words of length 43 or 44
    target_words = [word for word in words if len(word) in [43, 44]]
    
    return target_words, words

# Get results
results, all_words = extract_ca(sample)

# Print results with their lengths
for word in results:
    print(f"Length {len(word)}: {word}")
# Out:
# Length 44: EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# Length 44: 6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN

# %%
print(sample)
# Out:
# nitter
# Tweets
# Users
# Elon Musk
# @elonmusk
# 14m
# 💯😂
# Gunther Eagleman™
# @GuntherEagleman
# 56m
# My God the Democrat Party is completely unhinged.
#
# Trump and Elon broke them all!
# 1,291
# 1,257
# 42
# 11,363
# Elon Musk
# @elonmusk
# 16m
# nitter.net/i/broadcasts/1MYGNMlzV…
# 899
# 1,147
# 52
# 8,961
# Elon Musk
# @elonmusk
# 20m
# 🇺🇸🇺🇸
# Senator Todd Young
# @SenToddYoung
# 8h
# Replying to @SenToddYoung
# Having now secured these commitments, I will support Tulsi’s nomination and look forward to working with her to protect our national security.
# 652
# 808
# 19
# 9,112
# Elon Musk
# @elonmusk
# 20m
# Interesting
#
# Source: BBC, wttw, DOJ, @nayibbukele, @marcorubio
# 657
# 1,262
# 57
# 7,390
# Bobby Shmurda
# @Shmurda
# 29m
# Get Some money...
#
# Qyzj938d1J8rZ7iQvWWgQq62TjWegTrXhGFGjigpump
# 269
# 256
# 23
# 421
# Elon Musk
# @elonmusk
# 49m
# Autism Capital 🧩
# Enable hls playback
# 1,541
# 2,737
# 118
# 19,546
# 0
# John Wang
# @j0hnwang
# 1h
# Replying to @srachasaucee @jessepollak @CoinbaseDev
# this is the content i live for
# 1
# 1
# John Wang
# @j0hnwang
# 1h
# Replying to @khushkhushkhush @A_StarVC @aaruHQ
# congratz and good luck w aaru!
# 2
# Elon Musk
# @elonmusk
# 1h
# Did you know that over $100 billion dollars in COVID payments was stolen by professional foreign fraud rings?
# Crémieux
# @cremieuxrecueil
# 12 Dec 2024
# The COVID era Paycheck Protection Program was defrauded at an incredible scale. People received PPP loans for total nonsense at stunning rates.
#
# Thread of funny claims.
#
# Dodge Hellcat LLC
# 4,997
# 12,336
# 709
# 53,573
# Elon Musk
# @elonmusk
# 1h
# Replying to @cremieuxrecueil
# 😂
# 114
# 29
# 8
# 588
# Elon Musk
# @elonmusk
# 1h
# Replying to @cremieuxrecueil
# Noted
# 68
# 25
# 5
# 542
# Bobby Shmurda
# @Shmurda
# 1h
# Get ready guys bro about to drop a banger on @solana
# 262
# 467
# 24
# 1,173
# Elon Musk
# @elonmusk
# 2h
# Replying to @AutismCapital @DOGE
# 😂💯
# 357
# 113
# 8
# 4,521
# Elon Musk
# @elonmusk
# 3h
# Awesome 😎
# Secretary Marco Rubio
# @SecRubio
# 7h
# Very productive meeting with Salvadoran President @nayibbukele. His commitment to accept and incarcerate criminals from any country, including from violent gangs like MS-13 and Tren de Aragua, will make America safer. In an extraordinary gesture never before extended by any country, President Bukele offered to house in his jails dangerous American criminals, including US citizens and legal residents.
# 1,891
# 3,384
# 110
# 28,777
# Elon Musk
# @elonmusk
# 3h
# Replying to @RealAlexJones
# Wow
# 220
# 214
# 12
# 2,728
# Elon Musk
# @elonmusk
# 3h
# Replying to @PirateWires
# 🤣 @DavidSacks
# 148
# 51
# 5
# 1,217
# Elon Musk
# @elonmusk
# 3h
# Replying to @risingsilent @JackPosobiec
# 💯
# 83
# 55
# 4
# 1,432
# Elon Musk
# @elonmusk
# 3h
# 🎯
# Dinesh D'Souza
# @DineshDSouza
# 8h
# The simple truth is @elonmusk publicly exposed the Great Ripoff.
#
# Now the ripoff artists—the beneficiaries of the scheme—are furious.
#
# What they say: “We stand to lose civilization, our democracy, our very system of government.”
#
# What they mean: “We stand to lose our racket”
# 1,919
# 6,062
# 136
# 42,978
# Load more

# %%
sample
# Out:
